# %% [markdown]
# # Visualizing Inference Predictions
#
# Note: plots are colored based on the relative difference between values. Lower values are dark, while higher values are brighter.

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0,'../code')
from general_utils import plot_mat_together,plot_mat_hist_together,plot_single_mat,plot_single_mat_hist

# %%
current_cmap = plt.cm.get_cmap()
current_cmap.set_bad(color='#ffb6c1') # replaces NaNs with this color

# %% [markdown]
# ## Same-year Predictions

# %% [markdown]
# ### Standard NN

# %%
mass_balance_matrix_s = np.load("../model_output/inference/mass_balance_matrix_s.npy")
mass_balance_matrix_w = np.load("../model_output/inference/mass_balance_matrix_w.npy")
combined_mb_matrix = np.load("../model_output/inference/combined_mb_matrix.npy")

# %%
plot_mat_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_mat_hist_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_single_mat(combined_mb_matrix)

# %%
plot_single_mat_hist(combined_mb_matrix)

# %% [markdown]
# ### GP Modeling - MCMC

# %%
mass_balance_matrix_s = np.load("../model_output/inference_mcmc/mass_balance_matrix_s.npy")
mass_balance_matrix_w = np.load("../model_output/inference_mcmc/mass_balance_matrix_w.npy")
combined_mb_matrix = np.load("../model_output/inference_mcmc/combined_mb_matrix.npy")
mb_variance_matrix_s = np.load("../model_output/inference_mcmc/mb_variance_matrix_s.npy")
mb_variance_matrix_w = np.load("../model_output/inference_mcmc/mb_variance_matrix_w.npy")

# %%
plot_mat_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_mat_hist_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_mat_together(mb_variance_matrix_s,mb_variance_matrix_w,title_1="Summer Variance",title_2="Winter Variance")

# %%
plot_single_mat(combined_mb_matrix)

# %%
plot_single_mat_hist(combined_mb_matrix)

# %% [markdown]
# ## Time-series Predictions

# %% [markdown]
# ### Standard NN

# %%
mass_balance_matrix_s = np.load("../model_output/inference_time/mass_balance_matrix_s.npy")
mass_balance_matrix_w = np.load("../model_output/inference_time/mass_balance_matrix_w.npy")
combined_mb_matrix = np.load("../model_output/inference_time/combined_mb_matrix.npy")

# %%
plot_mat_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_mat_hist_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_single_mat(combined_mb_matrix)

# %%
plot_single_mat_hist(combined_mb_matrix)

# %% [markdown]
# ### GP Modeling - MCMC

# %%
mass_balance_matrix_s = np.load("../model_output/inference_mcmc_time/mass_balance_matrix_s.npy")
mass_balance_matrix_w = np.load("../model_output/inference_mcmc_time/mass_balance_matrix_w.npy")
combined_mb_matrix = np.load("../model_output/inference_mcmc_time/combined_mb_matrix.npy")
mb_variance_matrix_s = np.load("../model_output/inference_mcmc_time/mb_variance_matrix_s.npy")
mb_variance_matrix_w = np.load("../model_output/inference_mcmc_time/mb_variance_matrix_w.npy")

# %%
plot_mat_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_mat_hist_together(mass_balance_matrix_s,mass_balance_matrix_w)

# %%
plot_mat_together(mb_variance_matrix_s,mb_variance_matrix_w,title_1="Summer Variance",title_2="Winter Variance")

# %%
plot_single_mat(combined_mb_matrix)

# %%
plot_single_mat_hist(combined_mb_matrix)
